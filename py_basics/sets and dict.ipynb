# %%
rule 1= set do not have mutable data types
rule 2= set dont have indexing
set only have distinct values
sets are mutable data types
sets follow hashing

# %%
a=set()
print(type(a))
# Out:
# <class 'set'>

# %%
set1={"w",2,3,3}
print(set1)
for i in set1:
    print(i)
# Out:
# {2, 3, 'w'}
# 2
# 3
# w

# %%
a={1,2,'hi',(21,"www")}
print(a)
# the output shows indexing dont work in sets
# Out:
# {1, 2, (21, 'www'), 'hi'}

# %%
c={3,4,5}
b={3,4,5}
print(b.issuperset(c))
# Out:
# True

# %%
s={1,2,3,4}
e={4,5,6,7}
print(s.union(e))
print(s.intersection(e))
print(s.difference(e))
# Out:
# {1, 2, 3, 4, 5, 6, 7}
# {4}
# {1, 2, 3}

# %%
dict1={1:"aryan",2:"rahul"}
# print(dict1[2])
for i in dict1:
    print(dict1[i])
dict1["name"]="hehe"
print(dict1)
# Out:
# aryan
# rahul
# {1: 'aryan', 2: 'rahul', 'name': 'hehe'}
