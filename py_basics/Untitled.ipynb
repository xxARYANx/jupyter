# %%
n=5
for i in range(n):
    for j in range (n):
        if i==0 or i==n-1 or j==0 or j==n-1:
            print("*",end="")
        else:
            print("",end=" ")
    print()
# Out:
# *****
# *   *
# *   *
# *   *
# *****

# %%
print("ho")
# Out:
# ho

# %%
import matplotlib

# %%
matplotlib.pyplot(a:0)
# Out:
#   Cell In[3], line 1
#     matplotlib.pyplot(a:0)
#                        ^
# SyntaxError: invalid syntax
