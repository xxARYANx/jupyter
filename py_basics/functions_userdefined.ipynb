# %%
def myword():
    print("hi babaji")
myword()
myword()
myword()
# Out:
# hi babaji
# hi babaji
# hi babaji

# %%
def stud(name):
    print("my name is",name)
stud("aryan")
# Out:
# my name is aryan

# %%
def bill(n):
    if n<=500:
        print(n*5)
    elif n<=700:
        print(n*10)
    elif n<=1000:
        print(n*10)
    else:
        print(n*20)
bill(1001)
# Out:
# 20020

# %%
def my_func(word):
    print(word,"this is my word")

my_func("Aryan")
# Out:
# Aryan this is my word
