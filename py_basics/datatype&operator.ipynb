# %%
aryan="a"
print(aryan)
print("aryan")
# Out:
# a
# aryan

# %%
a,b,c=1,2,3
print(a,b,c)
x=y=z="orange"
print(x)
print(y)
print(z)
# Out:
# 1 2 3
# orange
# orange
# orange

# %% [markdown]
# # Data types

# %%
var1=9
print(var1)
print(type(var1))
# Out:
# 9
# <class 'int'>

# %%
var2=9.5
print(var2)
print(type(var2))
# Out:
# 9.5
# <class 'float'>

# %%
var3="stringgg"
print(type(var3))
# Out:
# <class 'str'>

# %%
var4=3+2j
print(var4)
print(type(var4))
# Out:
# (3+2j)
# <class 'complex'>

# %%
string2="aryan"
print(type(string2))
# Out:
# <class 'str'>

# %%
a=[1,2,3,4,5,6]
print(a)
print(type(a))
# Out:
# [1, 2, 3, 4, 5, 6]
# <class 'list'>

# %%
a=(1,2,3,4,5,6)
print(a)
print(type(a))
# Out:
# (1, 2, 3, 4, 5, 6)
# <class 'tuple'>

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          tuple    n=6
# string2    str      aryan
