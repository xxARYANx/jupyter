# %%
a="hello"
print(a[3])
# Out:
# l

# %%
a='string'
print(a+" ho")
# Out:
# string ho

# %%
a="five"
print(a*5)
# Out:
# fivefivefivefivefive

# %%
print("aryan">"ryan")
# the reason for false is the string gets compared lexiographically
# Out:
# False

# %%
# empty string ko py false bolta h and non empty ko true in case of logical operation
a=""
b="aryan"
x="a/yan"
print(b and x)
print(x and b)
print(a and b) #this will return empty string as mentioned above
print(a or b)
print(not a)
print(not b)
# Out:
# a/yan
# aryan
#
# aryan
# True
# False

# %%
# a="Aryan"
# print(a[1:])
a="Aryan"
print(a[1::2])
# Out:
# ra

# %%
a="Aryan"
print(a[::-1])
# Out:
# nayrA

# %% [markdown]
# ## string function

# %% [markdown]
# ### format

# %%
print("hello my name is {} and my age is {} and and and i am the {}".format("Aryan",20,"best"))
print("hello my name is {2} and my age is {1} and and and i am the {0}".format("Aryan",20,"best"))
print("hello my name is {name} and my age is {age} and and and i am the {chu}".format(name="Aryan",age=20,hehe="best",chu="tiya"))
# Out:
# hello my name is Aryan and my age is 20 and and and i am the best
# hello my name is best and my age is 20 and and and i am the Aryan
# hello my name is Aryan and my age is 20 and and and i am the tiya

# %%
a="aryan"
print(len(a))
# Out:
# 5

# %%
a="desi"
print(sorted(a))
print(max(a))
print(min(a))
# Out:
# ['d', 'e', 'i', 's']
# s
# d

# %%
a="ooo"
print(a.count('a'))
print(a.count('o'))
# Out:
# 0
# 3

# %% [markdown]
# ### replace

# %%
a="aryan"
print(a.replace(a[1],"h"))
# Out:
# ahyan

# %%
a="aryan"
print(a.replace("a","h"))
# Out:
# hryhn

# %% [markdown]
# ### upper() & lower()

# %%
a="hi how are you"
print(a.upper())
# Out:
# HI HOW ARE YOU

# %%
a="HI HOW ARE YOU"
print(a.lower())
# Out:
# hi how are you

# %% [markdown]
# ### to convert the first word of sentence into capital

# %%
a="hello how are you"
print(a.title())
# Out:
# Hello How Are You

# %% [markdown]
# ### find()

# %%
a="hi how are you"
print(a.find("how"))
# Out:
# 3

# %% [markdown]
# ## membership operator

# %%
a="aryan"
print("s" in a)
print("r" in a)
print("s" not in a)
# Out:
# False
# True
# True

# %% [markdown]
# ## split

# %%
print("hey u cutiw bootiful".split())
print("hey u cutiw bootiful".split("u"))
# Out:
# ['hey', 'u', 'cutiw', 'bootiful']
# ['hey ', ' c', 'tiw bootif', 'l']

# %%
a="hi i am aryan"
x=a.split(" ")
l=[]
print(x)
for i in x:
    l.append(i.capitalize())
print(" ".join(l))
# Out:
# ['hi', 'i', 'am', 'aryan']
# Hi I Am Aryan
