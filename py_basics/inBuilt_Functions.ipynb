# %% [markdown]
# ## abs function - gives the absolute value i.e -7=7;

# %%
aryan,age=abs(-8.95),abs(-20)
print(aryan)
print(age)
# Out:
# 8.95
# 20

# %%
var1=abs(4+4j)
print(var1)
# Out:
# 5.656854249492381

# %% [markdown]
# ## bin function for binary

# %%
x=bin(8)
y=bin(32)
z=bin(56)
print(x,y,z)
# Out:
# 0b1000 0b100000 0b111000

# %% [markdown]
# ## bytes

# %%
x=bytes(8)
print(x)
# Out:
# b'\x00\x00\x00\x00\x00\x00\x00\x00'

# %% [markdown]
# ## chr function

# %%
var1= chr(97)
var2= chr(65)
print(var1,var2)
# Out:
# a A

# %% [markdown]
# ## float,int and str fun

# %%
x=int (8.5)
print(x)
print(type(x))
y=float(8)
print(y)
print(type(y))
s=str(9)
print(s)
print(type(s))
# Out:
# 8
# <class 'int'>
# 8.0
# <class 'float'>
# 9
# <class 'str'>

# %% [markdown]
# ## help function for providing the info about any other func

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating-point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...
