# %% [markdown]
# ## if,if else , if elif else

# %%
a=9
if a>3:
    print("a is greater",a)
else:
    print("bkk")
# Out:
# a is greater 9

# %%
a=11
if a>3 and a<=10:
    print("if",a)
elif a>10 and a<100:
    print("elif")
else:
    print("else")
# Out:
# elif
